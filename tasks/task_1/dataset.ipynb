# %% [markdown]
# # Investigating the dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas

from utils import load_data_from_json, array_to_rgb_image, array_to_rgb_histogram

# %% [markdown]
# ## Read in the raw data from JSON file
#
# Note that ``obj?`` is an IPython-specific syntax that is similar to ``help(obj)``

# %%
load_data_from_json?

# %%
RAW_DATA = load_data_from_json('C:\\Users\\s2113022\\Documents\\GitHub\\ceres-workshop\\tasks\\task_1\\data')

dataframe = pandas.DataFrame(RAW_DATA)

# %% [markdown]
# ## Dataset structure and properties
#
# Use the cells below to investigate the structure and properties of the dataset.

# %%
a = np.array(dataframe['data'][0]).reshape(3,80,80)

# %%
dataframe[dataframe['labels'] == 0]['data']
# Out:
# 1000    [73, 75, 75, 73, 75, 75, 76, 77, 78, 78, 80, 8...
# 1001    [165, 171, 163, 152, 142, 133, 132, 133, 130, ...
# 1002    [198, 202, 210, 214, 217, 221, 223, 222, 223, ...
# 1003    [155, 170, 175, 181, 172, 150, 124, 125, 129, ...
# 1004    [74, 80, 80, 81, 81, 81, 82, 81, 83, 84, 80, 8...
#                               ...
# 3995    [126, 122, 124, 138, 165, 186, 195, 199, 203, ...
# 3996    [130, 134, 139, 128, 117, 126, 141, 147, 142, ...
# 3997    [171, 135, 118, 140, 145, 144, 154, 165, 139, ...
# 3998    [85, 90, 94, 95, 94, 92, 93, 96, 93, 94, 94, 9...
# 3999    [122, 122, 126, 126, 142, 153, 174, 190, 185, ...
# Name: data, Length: 3000, dtype: object

# %%
array_to_rgb_histogram(a)

# %%
len(dataframe['data'][0])
# Out:
# 19200

# %% [markdown]
# ## Sample images
#
# Use the cells below to display some of the images from the dataset, and histograms of their red/blue/green pixel intensities.

# %%
array_to_rgb_image?
#array_to_rgb_histogram?

# %% [markdown]
# ## Visualisation of the dataset on a map
#
# Use the cells below to display a visualisation of the locations of the images on a map.
#
# **This is an extension task!**
